# %% [markdown]
# <a href="https://colab.research.google.com/github/pedrodatascientist/usefulcode/blob/main/Consumindo_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Usando requests para consumir uma API

# %%
import requests
import json
import pandas as pd

# %%
#Obtendo dados através do get
#O método GET é usado para recuperar informações de um determinado servidor usando um determinado URI
url = requests.get('https://economia.awesomeapi.com.br/all')

# %%
#Visualizando json
cotacao = url.json()
cotacao
# Out:
# {'ARS': {'ask': '0.0617',
#   'bid': '0.0617',
#   'code': 'ARS',
#   'codein': 'BRL',
#   'create_date': '2021-03-11 12:19:00',
#   'high': '0.0625',
#   'low': '0.0614',
#   'name': 'Peso Argentino',
#   'pctChange': '-1.28',
#   'timestamp': '1615475937',
#   'varBid': '-0.0008'},
#  'AUD': {'ask': '4.3363',
#   'bid': '4.3342',
#   'code': 'AUD',
#   'codein': 'BRL',
#   'create_date': '2021-03-11 12:18:59',
#   'high': '4.4156',
#   'low': '4.3282',
#   'name': 'Dólar Australiano',
#   'pctChange': '-1.17',
#   'timestamp': '1615475937',
#   'varBid': '-0.0514'},
#  'BTC': {'ask': '320499',
#   'bid': '320120',
#   'code': 'BTC',
#   'codein': 'BRL',
#   'create_date': '2021-03-11 12:19:00',
#   'high': '325000',
#   'low': '312000',
#   'name': 'Bitcoin',
#   'pctChange': '0.63',
#   'timestamp': '1615475938',
#   'varBid': '1999'},
#  'CAD': {'ask': '4.4472',
#   'bid': '4.4442',
#   'code': 'CAD',
#   'codein': 'BRL',
#   'create_date': '2021-03-11 12:18:59',
# ...

# %%
#Tranformando o json num obejto dataframe do pandas
df = pd.DataFrame(data=cotacao).T
df
# Out:
#      code codein  ...   timestamp          create_date
# USD   USD    BRL  ...  1615475938  2021-03-11 12:19:00
# USDT  USD   BRLT  ...  1615475280  2021-03-11 12:08:50
# CAD   CAD    BRL  ...  1615475936  2021-03-11 12:18:59
# EUR   EUR    BRL  ...  1615475937  2021-03-11 12:19:00
# GBP   GBP    BRL  ...  1615475938  2021-03-11 12:19:00
# ARS   ARS    BRL  ...  1615475937  2021-03-11 12:19:00
# BTC   BTC    BRL  ...  1615475938  2021-03-11 12:19:00
# LTC   LTC    BRL  ...  1615475938  2021-03-11 12:18:59
# JPY   JPY    BRL  ...  1615475925  2021-03-11 12:18:46
# CHF   CHF    BRL  ...  1615475937  2021-03-11 12:18:59
# AUD   AUD    BRL  ...  1615475937  2021-03-11 12:18:59
# CNY   CNY    BRL  ...  1615475884  2021-03-11 12:18:06
# ILS   ILS    BRL  ...  1615475887  2021-03-11 12:18:08
# ETH   ETH    BRL  ...  1610415652  2021-01-11 22:40:52
# XRP   XRP    BRL  ...  1615475938  2021-03-11 12:18:59
#
# [15 rows x 11 columns]
